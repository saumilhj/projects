# %% [markdown]
# <a href="https://colab.research.google.com/github/saumilhj/projects/blob/main/BFS.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# **BLACK FRIDAY SALE**

# %% [markdown]
# Dataset from Kaggle: https://www.kaggle.com/datasets/rajeshrampure/black-friday-sale

# %%
import pandas as pd
import plotly.express as px

# %% [markdown]
# Import data

# %%
df = pd.read_csv('data_bfs.csv')

# %%
df.head()
# Out:
#    User_ID Product_ID Gender   Age  Occupation City_Category  \
# 0  1000001  P00069042      F  0-17          10             A
# 1  1000001  P00248942      F  0-17          10             A
# 2  1000001  P00087842      F  0-17          10             A
# 3  1000001  P00085442      F  0-17          10             A
# 4  1000002  P00285442      M   55+          16             C
#
#   Stay_In_Current_City_Years  Marital_Status  Product_Category_1  \
# 0                          2               0                   3
# 1                          2               0                   1
# 2                          2               0                  12
# 3                          2               0                  12
# 4                         4+               0                   8
#
#    Product_Category_2  Product_Category_3  Purchase
# 0                 NaN                 NaN      8370
# 1                 6.0                14.0     15200
# 2                 NaN                 NaN      1422
# 3                14.0                 NaN      1057
# 4                 NaN                 NaN      7969

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 550068 entries, 0 to 550067
# Data columns (total 12 columns):
#  #   Column                      Non-Null Count   Dtype
# ---  ------                      --------------   -----
#  0   User_ID                     550068 non-null  int64
#  1   Product_ID                  550068 non-null  object
#  2   Gender                      550068 non-null  object
#  3   Age                         550068 non-null  object
#  4   Occupation                  550068 non-null  int64
#  5   City_Category               550068 non-null  object
#  6   Stay_In_Current_City_Years  550068 non-null  object
#  7   Marital_Status              550068 non-null  int64
#  8   Product_Category_1          550068 non-null  int64
#  9   Product_Category_2          376430 non-null  float64
#  10  Product_Category_3          166821 non-null  float64
#  11  Purchase                    550068 non-null  int64
# dtypes: float64(2), int64(5), object(5)
# memory usage: 50.4+ MB

# %% [markdown]
# Check duplicates

# %%
df.duplicated().sum()
# Out:
# 0

# %% [markdown]
# Check NaN

# %%
df.isna().sum()
# Out:
# User_ID                            0
# Product_ID                         0
# Gender                             0
# Age                                0
# Occupation                         0
# City_Category                      0
# Stay_In_Current_City_Years         0
# Marital_Status                     0
# Product_Category_1                 0
# Product_Category_2            173638
# Product_Category_3            383247
# Purchase                           0
# dtype: int64

# %% [markdown]
# NaN values in product category imply that it was not bought. Hence, replace NaN value with 0.

# %%
df['Product_Category_2'] = df['Product_Category_2'].fillna(0)
df['Product_Category_3'] = df['Product_Category_3'].fillna(0)

# %%
df=df.astype({'Product_Category_2': 'int', 'Product_Category_3': 'int'})

# %% [markdown]
# Total customers and total products

# %%
print(f"Total customers = {df['User_ID'].nunique()}\n")
print(f"Total products sold:\nProduct Category 1 = {df['Product_Category_1'].sum()}\nProduct Category 2 = {df['Product_Category_2'].sum()}\nProduct Category 3 = {df['Product_Category_3'].sum()}")
# Out:
# Total customers = 5891
#
# Total products sold:
# Product Category 1 = 2972716
# Product Category 2 = 3704948
# Product Category 3 = 2113329

# %% [markdown]
# Spread of average spend by each customer

# %%
df_user_purchase = df.groupby(['User_ID'], as_index=False).mean()[['User_ID', 'Purchase']]
df_user_purchase.head()
# Out:
#    User_ID      Purchase
# 0  1000001   9545.514286
# 1  1000002  10525.610390
# 2  1000003  11780.517241
# 3  1000004  14747.714286
# 4  1000005   7745.292453

# %%
fig = px.histogram(df_user_purchase, x=df_user_purchase['Purchase'],
                   title='Spread of average spending by customers')
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script src="https://cdn.plot.ly/plotly-2.8.3.min.js"></script>                <div id="b07f25f6-2ac3-4e45-b708-a2aa2b84b612" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("b07f25f6-2ac3-4e45-b708-a2aa2b84b612")) {                    Plotly.newPlot(                        "b07f25f6-2ac3-4e45-b708-a2aa2b84b612",                        [{"alignmentgroup":"True","bingroup":"x","hovertemplate":"Purchase=%{x}<br>count=%{y}<extra></extra>","legendgroup":"","marker":{"color":"#636efa","pattern":{"shape":""}},"name":"","offsetgroup":"","orientation":"v","showlegend":false,"x":[9545.514285714286,10525.61038961039,11780.51724137931,14747.714285714286,7745.292452830188,8083.617021276596,13804.0,10345.363636363636,10243.086206896553,9728.744394618834,7957.471428571429,10981.90909090909,11898.783333333333,9817.615384615385,8954.940170940172,6840.454545454545,12399.95652173913,10994.705555555556,10055.64827586207,15478.916666666666,9078.5,8204.576923076924,9771.91812865497,9362.324675324675,12152.40909090909,7106.9646017699115,10688.904761904761,9062.456140350878,13388.48076923077,8438.193548387097,7752.40625,9543.708333333334,8983.416666666666,8079.83,7399.126126126126,11582.85,8279.0,9325.341463414634,9177.5,11864.28,9851.142857142857,9836.5,5731.444444444444,6606.142857142857,9378.785714285714,8250.011834319526,12206.066666666668,7952.4,8030.88,12453.309523809523,11327.244031830238,7810.458333333333,9594.285714285714,10081.605263157895,7269.395348837209,11098.988505747126,7657.171875,7778.583333333333,7818.0,8913.539007092199,8789.84126984127,13187.25,13318.223880597016,10715.619047619048,9787.277777777777,7643.139534883721,8778.944444444445,8221.884615384615,9819.0625,8450.407407407407,10658.977611940298,11251.655172413793,9329.585585585586,11720.196078431372,6720.318181818182,6777.930232558139,7325.764705882353,10605.125,12250.529411764706,10944.203389830509,9999.22641509434,12596.59090909091,7834.1578947368425,12252.625,11008.837837837838,9980.242424242424,8019.714285714285,9566.576642335767,8803.375,7057.910313901345,11092.539130434783,7041.142857142857,10362.607142857143,10331.116279069767,10450.590361445784,11885.384615384615,7791.369230769231,10998.690476190477,17246.439393939392,7362.264367816092,15406.621212121212,7679.642857142857,15515.0,8044.8387096774195,8900.615384615385,8633.714285714286,10654.772727272728,10624.341463414634,9477.636363636364,13774.666666666666,10002.222222222223,8038.826923076923,10743.181818181818,9691.328621908127,10938.176470588236,7384.684210526316,10436.939393939394,14303.268292682927,10430.115384615385,9196.28409090909,9066.533333333333,14017.444444444445,11120.4,11712.61,10724.153846153846,14755.070588235294,15935.975,8313.666666666666,7676.4,8622.193548387097,8604.21568627451,9247.435897435897,6883.092511013216,10188.152,16031.027027027027,10953.094890510949,9972.242424242424,8850.615384615385,8866.441176470587,10155.216216216217,10638.5,6742.137931034483,9484.264705882353,11525.126315789474,10670.48377581121,11302.68263473054,9083.666666666666,9048.752650176679,7174.333333333333,8353.6,8041.885714285714,6671.037037037037,8949.142857142857,10270.792626728111,12338.2,9338.708333333334,8458.0,10242.728260869566,12479.236363636364,6028.527675276753,8655.166666666666,10578.754385964912,9553.884792626728,6451.275862068966,9621.285714285714,9107.370607028754,12508.53488372093,13928.266666666666,14201.066666666668,10173.701587301588,13631.732142857143,8532.95321637427,7992.125,12585.677419354839,8069.537313432836,7266.671641791045,8341.677419354839,10521.635294117646,9090.592592592593,10324.640625,10810.33962264151,13616.90625,11057.06779661017,9234.184426229509,9578.142857142857,10499.85,9612.111111111111,6904.176470588235,8442.063157894738,8704.60583941606,7275.75,9704.552462526766,11385.25,8450. ...

# %% [markdown]
# Average purchase per user maps very similar to the normal curve

# %% [markdown]
# Average spending based on age group and gender

# %%
df_age_gender = df.groupby(['Age', 'Gender'], as_index=False).mean()[['Age', 'Gender', 'Purchase']]
df_age_gender
# Out:
#       Age Gender     Purchase
# 0    0-17      F  8338.771985
# 1    0-17      M  9235.173670
# 2   18-25      F  8343.180201
# 3   18-25      M  9440.942971
# 4   26-35      F  8728.251754
# 5   26-35      M  9410.337578
# 6   36-45      F  8959.844056
# 7   36-45      M  9453.193643
# 8   46-50      F  8842.098947
# 9   46-50      M  9357.471509
# 10  51-55      F  9042.449666
# 11  51-55      M  9705.094802
# 12    55+      F  9007.036199
# 13    55+      M  9438.195603

# %%
fig = px.bar(df_age_gender, y='Purchase', x='Age', color='Gender',
             title='Average spend of age groups segregated into gender',
             barmode='group')
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script src="https://cdn.plot.ly/plotly-2.8.3.min.js"></script>                <div id="1a85b89c-9785-47c3-88f9-6318315880eb" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("1a85b89c-9785-47c3-88f9-6318315880eb")) {                    Plotly.newPlot(                        "1a85b89c-9785-47c3-88f9-6318315880eb",                        [{"alignmentgroup":"True","hovertemplate":"Gender=F<br>Age=%{x}<br>Purchase=%{y}<extra></extra>","legendgroup":"F","marker":{"color":"#636efa","pattern":{"shape":""}},"name":"F","offsetgroup":"F","orientation":"v","showlegend":true,"textposition":"auto","x":["0-17","18-25","26-35","36-45","46-50","51-55","55+"],"xaxis":"x","y":[8338.771985048199,8343.180201396784,8728.251753625473,8959.844055944055,8842.098946889915,9042.449666464525,9007.036199095022],"yaxis":"y","type":"bar"},{"alignmentgroup":"True","hovertemplate":"Gender=M<br>Age=%{x}<br>Purchase=%{y}<extra></extra>","legendgroup":"M","marker":{"color":"#EF553B","pattern":{"shape":""}},"name":"M","offsetgroup":"M","orientation":"v","showlegend":true,"textposition":"auto","x":["0-17","18-25","26-35","36-45","46-50","51-55","55+"],"xaxis":"x","y":[9235.173670026948,9440.94297099904,9410.337578108805,9453.193643397752,9357.471509445573,9705.094801971545,9438.195603191036],"yaxis":"y","type":"bar"}],                        {"template":{"data":{"bar":[{"error_x":{"color":"#2a3f5f"},"error_y":{"color":"#2a3f5f"},"marker":{"line":{"color":"#E5ECF6","width":0.5},"pattern":{"fillmode":"overlay","size":10,"solidity":0.2}},"type":"bar"}],"barpolar":[{"marker":{"line":{"color":"#E5ECF6","width":0.5},"pattern":{"fillmode":"overlay","size":10,"solidity":0.2}},"type":"barpolar"}],"carpet":[{"aaxis":{"endlinecolor":"#2a3f5f","gridcolor":"white","linecolor":"white","minorgridcolor":"white","startlinecolor":"#2a3f5f"},"baxis":{"endlinecolor":"#2a3f5f","gridcolor":"white","linecolor":"white","minorgridcolor":"white","startlinecolor":"#2a3f5f"},"type":"carpet"}],"choropleth":[{"colorbar":{"outlinewidth":0,"ticks":""},"type":"choropleth"}],"contour":[{"colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]],"type":"contour"}],"contourcarpet":[{"colorbar":{"outlinewidth":0,"ticks":""},"type":"contourcarpet"}],"heatmap":[{"colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]],"type":"heatmap"}],"heatmapgl":[{"colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]],"type":"heatmapgl"}],"histogram":[{"marker":{"pattern":{"fillmode":"overlay","size":10,"solidity":0.2}},"type":"histogram"}],"histogram2d":[{"colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]],"type":"histogram2d"}],"histogram2dcontour":[{"colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0, ...

# %% [markdown]
# Male spending is consistently higher than female spending for all age groups. However, variance in total spend by all age groups is almost negligible.

# %% [markdown]
# Correlation between city and average purchase amount split by age groups

# %%
df_city_age = df.groupby(['City_Category', 'Age'], as_index=False).mean()[['City_Category', 'Age','Purchase']]
df_city_age
# Out:
#    City_Category    Age     Purchase
# 0              A   0-17  8615.110456
# 1              A  18-25  8833.734084
# 2              A  26-35  8952.503004
# 3              A  36-45  8990.333997
# 4              A  46-50  8348.526752
# 5              A  51-55  9508.505001
# 6              A    55+  8485.945424
# 7              B   0-17  8917.295308
# 8              B  18-25  9031.706985
# 9              B  26-35  9149.193178
# 10             B  36-45  9107.901067
# 11             B  46-50  9247.927129
# 12             B  51-55  9340.911392
# 13             B    55+  9803.560635
# 14             C   0-17  9059.503299
# 15             C  18-25  9696.570919
# 16             C  26-35  9835.388993
# 17             C  36-45  9882.012654
# 18             C  46-50  9533.184023
# 19             C  51-55  9780.380806
# 20             C    55+  9385.316939

# %%
fig = px.bar(df_city_age, x='Age', y='Purchase', color='City_Category',
             barmode='group')
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script src="https://cdn.plot.ly/plotly-2.8.3.min.js"></script>                <div id="0d427b43-e126-4964-b1f9-6b2a23c02008" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("0d427b43-e126-4964-b1f9-6b2a23c02008")) {                    Plotly.newPlot(                        "0d427b43-e126-4964-b1f9-6b2a23c02008",                        [{"alignmentgroup":"True","hovertemplate":"City_Category=A<br>Age=%{x}<br>Purchase=%{y}<extra></extra>","legendgroup":"A","marker":{"color":"#636efa","pattern":{"shape":""}},"name":"A","offsetgroup":"A","orientation":"v","showlegend":true,"textposition":"auto","x":["0-17","18-25","26-35","36-45","46-50","51-55","55+"],"xaxis":"x","y":[8615.110455974842,8833.734083893227,8952.503003593463,8990.333997069542,8348.526751676089,9508.505000819807,8485.945424013435],"yaxis":"y","type":"bar"},{"alignmentgroup":"True","hovertemplate":"City_Category=B<br>Age=%{x}<br>Purchase=%{y}<extra></extra>","legendgroup":"B","marker":{"color":"#EF553B","pattern":{"shape":""}},"name":"B","offsetgroup":"B","orientation":"v","showlegend":true,"textposition":"auto","x":["0-17","18-25","26-35","36-45","46-50","51-55","55+"],"xaxis":"x","y":[8917.295308187673,9031.70698545564,9149.19317784766,9107.901067271734,9247.927129275704,9340.911391691561,9803.56063541263],"yaxis":"y","type":"bar"},{"alignmentgroup":"True","hovertemplate":"City_Category=C<br>Age=%{x}<br>Purchase=%{y}<extra></extra>","legendgroup":"C","marker":{"color":"#00cc96","pattern":{"shape":""}},"name":"C","offsetgroup":"C","orientation":"v","showlegend":true,"textposition":"auto","x":["0-17","18-25","26-35","36-45","46-50","51-55","55+"],"xaxis":"x","y":[9059.503299171698,9696.570919038715,9835.388993328173,9882.01265433823,9533.184023066486,9780.380806220584,9385.316939462762],"yaxis":"y","type":"bar"}],                        {"template":{"data":{"bar":[{"error_x":{"color":"#2a3f5f"},"error_y":{"color":"#2a3f5f"},"marker":{"line":{"color":"#E5ECF6","width":0.5},"pattern":{"fillmode":"overlay","size":10,"solidity":0.2}},"type":"bar"}],"barpolar":[{"marker":{"line":{"color":"#E5ECF6","width":0.5},"pattern":{"fillmode":"overlay","size":10,"solidity":0.2}},"type":"barpolar"}],"carpet":[{"aaxis":{"endlinecolor":"#2a3f5f","gridcolor":"white","linecolor":"white","minorgridcolor":"white","startlinecolor":"#2a3f5f"},"baxis":{"endlinecolor":"#2a3f5f","gridcolor":"white","linecolor":"white","minorgridcolor":"white","startlinecolor":"#2a3f5f"},"type":"carpet"}],"choropleth":[{"colorbar":{"outlinewidth":0,"ticks":""},"type":"choropleth"}],"contour":[{"colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]],"type":"contour"}],"contourcarpet":[{"colorbar":{"outlinewidth":0,"ticks":""},"type":"contourcarpet"}],"heatmap":[{"colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]],"type":"heatmap"}],"heatmapgl":[{"colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]],"type":"heatmapgl"}],"histogram":[{"marker":{"pattern":{"fillmode":"overlay","size" ...

# %% [markdown]
# City C shows higher average spend by customers of all age groups except 55+

# %% [markdown]
# Average purchase based on occupation

# %%
df_occ = df.groupby(['Occupation'], as_index=False).mean()[['Occupation', 'Purchase']].sort_values(by='Purchase')
df_occ['Occupation'] = df_occ['Occupation'].astype(str)
df_occ
# Out:
#    Occupation     Purchase
# 9           9  8637.743761
# 19         19  8710.627231
# 20         20  8836.494905
# 2           2  8952.481683
# 1           1  8953.193270
# 10         10  8959.355375
# 0           0  9124.428588
# 18         18  9169.655844
# 3           3  9178.593088
# 11         11  9213.845848
# 4           4  9213.980251
# 6           6  9256.535691
# 13         13  9306.351061
# 5           5  9333.149298
# 16         16  9394.464349
# 7           7  9425.728223
# 14         14  9500.702772
# 8           8  9532.592497
# 15         15  9778.891163
# 12         12  9796.640239
# 17         17  9821.478236

# %%
fig = px.bar(df_occ, y='Occupation', x='Purchase',color='Purchase', orientation='h', color_continuous_scale=px.colors.sequential.Plasma_r)
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script src="https://cdn.plot.ly/plotly-2.8.3.min.js"></script>                <div id="1df00f2c-8c23-45ac-897e-0b039d522c88" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("1df00f2c-8c23-45ac-897e-0b039d522c88")) {                    Plotly.newPlot(                        "1df00f2c-8c23-45ac-897e-0b039d522c88",                        [{"alignmentgroup":"True","hovertemplate":"Purchase=%{marker.color}<br>Occupation=%{y}<extra></extra>","legendgroup":"","marker":{"color":[8637.74376092831,8710.62723082378,8836.49490495203,8952.481683466225,8953.193269514612,8959.355375096675,9124.428587839973,9169.655844155845,9178.593087818697,9213.84584843777,9213.980251147868,9256.535691476296,9306.351061076604,9333.149297856615,9394.46434905995,9425.728222819745,9500.702771979933,9532.592496765847,9778.891163173037,9796.640238622149,9821.478235896411],"coloraxis":"coloraxis","pattern":{"shape":""}},"name":"","offsetgroup":"","orientation":"h","showlegend":false,"textposition":"auto","x":[8637.74376092831,8710.62723082378,8836.49490495203,8952.481683466225,8953.193269514612,8959.355375096675,9124.428587839973,9169.655844155845,9178.593087818697,9213.84584843777,9213.980251147868,9256.535691476296,9306.351061076604,9333.149297856615,9394.46434905995,9425.728222819745,9500.702771979933,9532.592496765847,9778.891163173037,9796.640238622149,9821.478235896411],"xaxis":"x","y":["9","19","20","2","1","10","0","18","3","11","4","6","13","5","16","7","14","8","15","12","17"],"yaxis":"y","type":"bar"}],                        {"template":{"data":{"bar":[{"error_x":{"color":"#2a3f5f"},"error_y":{"color":"#2a3f5f"},"marker":{"line":{"color":"#E5ECF6","width":0.5},"pattern":{"fillmode":"overlay","size":10,"solidity":0.2}},"type":"bar"}],"barpolar":[{"marker":{"line":{"color":"#E5ECF6","width":0.5},"pattern":{"fillmode":"overlay","size":10,"solidity":0.2}},"type":"barpolar"}],"carpet":[{"aaxis":{"endlinecolor":"#2a3f5f","gridcolor":"white","linecolor":"white","minorgridcolor":"white","startlinecolor":"#2a3f5f"},"baxis":{"endlinecolor":"#2a3f5f","gridcolor":"white","linecolor":"white","minorgridcolor":"white","startlinecolor":"#2a3f5f"},"type":"carpet"}],"choropleth":[{"colorbar":{"outlinewidth":0,"ticks":""},"type":"choropleth"}],"contour":[{"colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]],"type":"contour"}],"contourcarpet":[{"colorbar":{"outlinewidth":0,"ticks":""},"type":"contourcarpet"}],"heatmap":[{"colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]],"type":"heatmap"}],"heatmapgl":[{"colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]],"type":"heatmapgl"}],"histogram":[{"marker":{"pattern":{"fillmode":"overlay","size":10,"solidity":0.2}},"type":"histogram"}],"histogram2d":[{"colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.666666666666 ...

# %% [markdown]
# Occupation number 17, 12 and 15 show the top 3 highest average spending in order.
