# %% [markdown]
# <a href="https://colab.research.google.com/github/saumilhj/projects/blob/main/ANN_Wine_Classification.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# **WINE CLASSIFICATION WITH ANN**

# %% [markdown]
# Dataset from Kaggle: https://www.kaggle.com/datasets/nareshbhat/wine-quality-binary-classification

# %% [markdown]
# ###  Import libraries

# %%
import numpy as np
import pandas as pd
import plotly.express as px

from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler

from tensorflow import keras
from keras import layers, callbacks, losses

# %% [markdown]
# ### Import data

# %%
df = pd.read_csv('wine_data.csv')
df.head()
# Out:
#    fixed acidity  volatile acidity  citric acid  residual sugar  chlorides  \
# 0            7.4              0.70         0.00             1.9      0.076
# 1            7.8              0.88         0.00             2.6      0.098
# 2            7.8              0.76         0.04             2.3      0.092
# 3           11.2              0.28         0.56             1.9      0.075
# 4            7.4              0.70         0.00             1.9      0.076
#
#    free sulfur dioxide  total sulfur dioxide  density    pH  sulphates  \
# 0                 11.0                  34.0   0.9978  3.51       0.56
# 1                 25.0                  67.0   0.9968  3.20       0.68
# 2                 15.0                  54.0   0.9970  3.26       0.65
# 3                 17.0                  60.0   0.9980  3.16       0.58
# 4                 11.0                  34.0   0.9978  3.51       0.56
#
#    alcohol quality
# 0      9.4     bad
# 1      9.8     bad
# 2      9.8     bad
# 3      9.8    good
# 4      9.4     bad

# %%
print(f'There are a total of {len(df.index)} records.')
# Out:
# There are a total of 1599 records.

# %% [markdown]
# Change target variable quality to binary values 1 and 0

# %%
df['quality'] = df['quality'].map({'good': 1, 'bad': 0})

# %% [markdown]
# ### Check NaN and duplicates

# %%
df.isna().sum()
# Out:
# fixed acidity           0
# volatile acidity        0
# citric acid             0
# residual sugar          0
# chlorides               0
# free sulfur dioxide     0
# total sulfur dioxide    0
# density                 0
# pH                      0
# sulphates               0
# alcohol                 0
# quality                 0
# dtype: int64

# %%
df[df.duplicated()]
# Out:
#       fixed acidity  volatile acidity  citric acid  residual sugar  chlorides  \
# 4               7.4             0.700         0.00            1.90      0.076
# 11              7.5             0.500         0.36            6.10      0.071
# 27              7.9             0.430         0.21            1.60      0.106
# 40              7.3             0.450         0.36            5.90      0.074
# 65              7.2             0.725         0.05            4.65      0.086
# ...             ...               ...          ...             ...        ...
# 1563            7.2             0.695         0.13            2.00      0.076
# 1564            7.2             0.695         0.13            2.00      0.076
# 1567            7.2             0.695         0.13            2.00      0.076
# 1581            6.2             0.560         0.09            1.70      0.053
# 1596            6.3             0.510         0.13            2.30      0.076
#
#       free sulfur dioxide  total sulfur dioxide  density    pH  sulphates  \
# 4                    11.0                  34.0  0.99780  3.51       0.56
# 11                   17.0                 102.0  0.99780  3.35       0.80
# 27                   10.0                  37.0  0.99660  3.17       0.91
# 40                   12.0                  87.0  0.99780  3.33       0.83
# 65                    4.0                  11.0  0.99620  3.41       0.39
# ...                   ...                   ...      ...   ...        ...
# 1563                 12.0                  20.0  0.99546  3.29       0.54
# 1564                 12.0                  20.0  0.99546  3.29       0.54
# 1567                 12.0                  20.0  0.99546  3.29       0.54
# 1581                 24.0                  32.0  0.99402  3.54       0.60
# 1596                 29.0                  40.0  0.99574  3.42       0.75
#
#       alcohol  quality
# 4         9.4        0
# 11       10.5        0
# 27        9.5        0
# 40       10.5        0
# 65       10.9        0
# ...       ...      ...
# 1563     10.1        0
# 1564     10.1        0
# 1567     10.1        0
# 1581     11.3        0
# 1596     11.0        1
#
# [240 rows x 12 columns]

# %%
df.drop_duplicates(keep='first', inplace=True)

# %% [markdown]
# ### Split data into features and target

# %%
X = df.drop('quality', axis=1)
y = df['quality']

# %% [markdown]
# Distribution of target

# %%
df.hist('quality')
# Out:
# array([[<AxesSubplot:title={'center':'quality'}>]], dtype=object)

# %% [markdown]
# The distribution for good and bad wine is fairly equal and not skewed

# %% [markdown]
# Spread of features

# %%
X_molten = X.melt()

# %%
fig = px.box(X_molten,x='variable', y='value', title='Spread of features', color='variable')
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script src="https://cdn.plot.ly/plotly-2.8.3.min.js"></script>                <div id="48bc1efa-46ea-42e2-af1e-ede1e4f09d3b" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("48bc1efa-46ea-42e2-af1e-ede1e4f09d3b")) {                    Plotly.newPlot(                        "48bc1efa-46ea-42e2-af1e-ede1e4f09d3b",                        [{"alignmentgroup":"True","hovertemplate":"variable=%{x}<br>value=%{y}<extra></extra>","legendgroup":"fixed acidity","marker":{"color":"#636efa"},"name":"fixed acidity","notched":false,"offsetgroup":"fixed acidity","orientation":"v","showlegend":true,"x":["fixed acidity","fixed acidity","fixed acidity","fixed acidity","fixed acidity","fixed acidity","fixed acidity","fixed acidity","fixed acidity","fixed acidity","fixed acidity","fixed acidity","fixed acidity","fixed acidity","fixed acidity","fixed acidity","fixed acidity","fixed acidity","fixed acidity","fixed acidity","fixed acidity","fixed acidity","fixed acidity","fixed acidity","fixed acidity","fixed acidity","fixed acidity","fixed acidity","fixed acidity","fixed acidity","fixed acidity","fixed acidity","fixed acidity","fixed acidity","fixed acidity","fixed acidity","fixed acidity","fixed acidity","fixed acidity","fixed acidity","fixed acidity","fixed acidity","fixed acidity","fixed acidity","fixed acidity","fixed acidity","fixed acidity","fixed acidity","fixed acidity","fixed acidity","fixed acidity","fixed acidity","fixed acidity","fixed acidity","fixed acidity","fixed acidity","fixed acidity","fixed acidity","fixed acidity","fixed acidity","fixed acidity","fixed acidity","fixed acidity","fixed acidity","fixed acidity","fixed acidity","fixed acidity","fixed acidity","fixed acidity","fixed acidity","fixed acidity","fixed acidity","fixed acidity","fixed acidity","fixed acidity","fixed acidity","fixed acidity","fixed acidity","fixed acidity","fixed acidity","fixed acidity","fixed acidity","fixed acidity","fixed acidity","fixed acidity","fixed acidity","fixed acidity","fixed acidity","fixed acidity","fixed acidity","fixed acidity","fixed acidity","fixed acidity","fixed acidity","fixed acidity","fixed acidity","fixed acidity","fixed acidity","fixed acidity","fixed acidity","fixed acidity","fixed acidity","fixed acidity","fixed acidity","fixed acidity","fixed acidity","fixed acidity","fixed acidity","fixed acidity","fixed acidity","fixed acidity","fixed acidity","fixed acidity","fixed acidity","fixed acidity","fixed acidity","fixed acidity","fixed acidity","fixed acidity","fixed acidity","fixed acidity","fixed acidity","fixed acidity","fixed acidity","fixed acidity","fixed acidity","fixed acidity","fixed acidity","fixed acidity","fixed acidity","fixed acidity","fixed acidity","fixed acidity","fixed acidity","fixed acidity","fixed acidity","fixed acidity","fixed acidity","fixed acidity","fixed acidity","fixed acidity","fixed acidity","fixed acidity","fixed acidity","fixed acidity","fixed acidity","fixed acidity","fixed acidity","fixed acidity","fixed acidity","fixed acidity","fixed acidity","fixed acidity","fixed acidity","fixed acidity","fixed acidity","fixed acidity","fixed acidity","fixed acidity","fixed acidity","fixed acidity","fixed acidity","fixed acidity","fixed acidity","fixed acidity","fixed acidity","fixed acidity","fixed acidity","fixed acidity","fixed acidity","fixed acidity","fixed acidity","fixed acidity","fixed acidity","fixed acidity","fixed acidity","fixed acidity","fixed acidity","fixed acidity","fixed acidity","fixed acidity","fixed acidity","fixed acidity","fixed acidity","fixed acidity","fixed acidity","fixed acidity","fixed acidity","fixed acidity","fixed acidity","fixed acidity","fixed acidity","fixed acidity","fixed acidity","fixed acidity","fixed acidity","fixed acidity","fixed acidity","fixed acidity","fixed acidity ...

# %% [markdown]
# As seen in the figure, the ranges of the feature variables are far away. So scaling will be required

# %% [markdown]
# ### Artifical Neural Network Implementation

# %%
X_train, X_val, y_train, y_val = train_test_split(X, y, test_size=0.25, stratify=y, random_state=10)

# %% [markdown]
# Apply scaling to X_train and X_test

# %%
scaler = StandardScaler()

X_train_scaled = scaler.fit_transform(X_train)
X_val_scaled = scaler.fit_transform(X_val)

# %% [markdown]
# #### Create neural network

# %% [markdown]
# Define early stopping

# %%
early_stop = callbacks.EarlyStopping(min_delta=0.001, patience=20, restore_best_weights=True)

# %% [markdown]
# Define model

# %%
model = keras.Sequential([
    layers.Dense(64, activation='relu', input_shape=[11]),
    layers.Dense(1, activation='sigmoid')
])

model.compile(optimizer='adam', loss=losses.BinaryCrossentropy(), metrics=['binary_accuracy'])

history = model.fit(X_train_scaled, y_train, validation_data=(X_val_scaled, y_val), callbacks=[early_stop], batch_size=16, epochs=500)
# Out:
# Epoch 1/500
# 64/64 [==============================] - 1s 4ms/step - loss: 0.6209 - binary_accuracy: 0.6428 - val_loss: 0.5877 - val_binary_accuracy: 0.7235
# Epoch 2/500
# 64/64 [==============================] - 0s 2ms/step - loss: 0.5376 - binary_accuracy: 0.7370 - val_loss: 0.5552 - val_binary_accuracy: 0.7382
# Epoch 3/500
# 64/64 [==============================] - 0s 4ms/step - loss: 0.5150 - binary_accuracy: 0.7419 - val_loss: 0.5458 - val_binary_accuracy: 0.7412
# Epoch 4/500
# 64/64 [==============================] - 0s 3ms/step - loss: 0.5045 - binary_accuracy: 0.7458 - val_loss: 0.5391 - val_binary_accuracy: 0.7500
# Epoch 5/500
# 64/64 [==============================] - 0s 3ms/step - loss: 0.4992 - binary_accuracy: 0.7439 - val_loss: 0.5368 - val_binary_accuracy: 0.7412
# Epoch 6/500
# 64/64 [==============================] - 0s 3ms/step - loss: 0.4947 - binary_accuracy: 0.7478 - val_loss: 0.5322 - val_binary_accuracy: 0.7441
# Epoch 7/500
# 64/64 [==============================] - 0s 4ms/step - loss: 0.4896 - binary_accuracy: 0.7576 - val_loss: 0.5295 - val_binary_accuracy: 0.7500
# Epoch 8/500
# 64/64 [==============================] - 0s 3ms/step - loss: 0.4868 - binary_accuracy: 0.7527 - val_loss: 0.5300 - val_binary_accuracy: 0.7412
# Epoch 9/500
# 64/64 [==============================] - 0s 3ms/step - loss: 0.4860 - binary_accuracy: 0.7527 - val_loss: 0.5248 - val_binary_accuracy: 0.7441
# Epoch 10/500
# 64/64 [==============================] - 0s 5ms/step - loss: 0.4818 - binary_accuracy: 0.7547 - val_loss: 0.5269 - val_binary_accuracy: 0.7412
# Epoch 11/500
# 64/64 [==============================] - 0s 4ms/step - loss: 0.4790 - binary_accuracy: 0.7556 - val_loss: 0.5244 - val_binary_accuracy: 0.7441
# Epoch 12/500
# 64/64 [==============================] - 0s 3ms/step - loss: 0.4786 - binary_accuracy: 0.7556 - val_loss: 0.5255 - val_binary_accuracy: 0.7559
# Epoch 13/500
# 64/64 [==============================] - 0s 4ms/step - loss: 0.4769 - binary_accuracy: 0.7605 - val_loss: 0.5273 - val_binary_accuracy: 0.7647
# Epoch 14/500
# 64/64 [==============================] - 0s 4ms/step - loss: 0.4735 - binary_accuracy: 0.7674 - val_loss: 0.5215 - val_binary_accuracy: 0.7471
# Epoch 15/500
# 64/64 [==============================] - 0s 3ms/step - loss: 0.4722 - binary_accuracy: 0.7684 - val_loss: 0.5212 - val_binary_accuracy: 0.7500
# Epoch 16/500
# 64/64 [==============================] - 0s 4ms/step - loss: 0.4689 - binary_accuracy: 0.7655 - val_loss: 0.5218 - val_binary_accuracy: 0.7588
# Epoch 17/500
# 64/64 [==============================] - 0s 3ms/step - loss: 0.4690 - binary_accuracy: 0.7684 - val_loss: 0.5263 - val_binary_accuracy: 0.7618
# Epoch 18/500
# 64/64 [==============================] - 0s 3ms/step - loss: 0.4688 - binary_accuracy: 0.7655 - val_loss: 0.5200 - val_binary_accuracy: 0.7647
# Epoch 19/500
# 64/64 [==============================] - 0s 2ms/step - loss: 0.4657 - binary_accuracy: 0.7723 - val_loss: 0.5197 - val_binary_accuracy: 0.7647
# Epoch 20/500
# 64/64 [==============================] - 0s 4ms/step - loss: 0.4634 - binary_accuracy: 0.7733 - val_loss: 0.5196 - val_binary_accuracy: 0.7647
# Epoch 21/500
# 64/64 [==============================] - 0s 6ms/step - loss: 0.4614 - binary_accuracy: 0.7684 - val_loss: 0.5166 - val_binary_accuracy: 0.7735
# Epoch 22/500
# 64/64 [==============================] - 0s 2ms/step - loss: 0.4604 - binary_accuracy: 0.7713 - val_loss: 0.5183 - val_binary_accuracy: 0.7647
# Epoch 23/500
# 64/64 [==============================] - 0s 3ms/step - loss: 0.4603 - binary_accuracy: 0.7723 - val_loss: 0.5168 - val_binary_accuracy: 0.7647
# Epoch 24/500
# 64/64 [==============================] - 0s 4ms/step - loss: 0.4585 - binary_accuracy: 0.7713 - val_loss: 0.5225 - val_binary_accuracy: 0.7647
# Epoch 25/500
# 64/64 [==============================] - 0s 5ms/step - loss: 0.4574 - binary_accuracy: 0.7743 - val_loss: 0.5192 - val_binary_accuracy: 0.7735
# Epoch 26/500
# 64/64 [==============================] - 0s 4ms/step - loss: 0.4561 - binary_accuracy: 0.7763 - val_loss: 0.5195 - val_binary_accuracy: 0.7735
# Epoch 27/500
# 64/64 [==============================] - 0s 3ms/step - loss: 0.4568 - binary_accuracy: 0.7743 - val_loss: 0.5238 - val_binary_accuracy: 0.7706
# Epoch 28/500
# 64/64 [==============================] - 0s 3ms/step - loss: 0.4552 - binary_accuracy: 0.7723 - val_loss: 0.5238 - val_binary_accuracy: 0.7706
# Epoch 29/500
# 64/64 [==============================] - 0s 4ms/step - loss: 0.4542 - binary_accuracy: 0.7753 - val_loss: 0.5163 - val_binary_accuracy: 0.7647
# Epoch 30/500
# 64/64 [==============================] - 0s 3ms/step - loss: 0.4537 - binary_accuracy: 0.7674 - val_loss: 0.5182 - val_binary_accuracy: 0.7794
# Epoch 31/500
# 64/64 [==============================] - 0s 5ms/step - loss: 0.4522 - binary_accuracy: 0.7792 - val_loss: 0.5208 - val_binary_accuracy: 0.7735
# Epoch 32/500
# 64/64 [==============================] - 0s 7ms/step - loss: 0.4513 - binary_accuracy: 0.7782 - val_loss: 0.5169 - val_binary_accuracy: 0.7676
# Epoch 33/500
# 64/64 [==============================] - 0s 6ms/step - loss: 0.4508 - binary_accuracy: 0.7802 - val_loss: 0.5199 - val_binary_accuracy: 0.7706
# Epoch 34/500
# 64/64 [==============================] - 0s 5ms/step - loss: 0.4497 - binary_accuracy: 0.7812 - val_loss: 0.5241 - val_binary_accuracy: 0.7735
# Epoch 35/500
# 64/64 [==============================] - 0s 6ms/step - loss: 0.4502 - binary_accuracy: 0.7743 - val_loss: 0.5227 - val_binary_accuracy: 0.7706
# Epoch 36/500
# 64/64 [==============================] - 0s 4ms/step - loss: 0.4482 - binary_accuracy: 0.7704 - val_loss: 0.5182 - val_binary_accuracy: 0.7706
# Epoch 37/500
# 64/64 [==============================] - 0s 3ms/step - loss: 0.4479 - binary_accuracy: 0.7812 - val_loss: 0.5224 - val_binary_accuracy: 0.7647
# Epoch 38/500
# 64/64 [==============================] - 0s 4ms/step - loss: 0.4463 - binary_accuracy: 0.7763 - val_loss: 0.5202 - val_binary_accuracy: 0.7647
# Epoch 39/500
# 64/64 [==============================] - 0s 3ms/step - loss: 0.4455 - binary_accuracy: 0.7792 - val_loss: 0.5235 - val_binary_accuracy: 0.7676
# Epoch 40/500
# 64/64 [==============================] - 0s 4ms/step - loss: 0.4449 - binary_accuracy: 0.7772 - val_loss: 0.5155 - val_binary_accuracy: 0.7647
# Epoch 41/500
# 64/64 [==============================] - 0s 4ms/step - loss: 0.4448 - binary_accuracy: 0.7841 - val_loss: 0.5230 - val_binary_accuracy: 0.7618
# Epoch 42/500
# 64/64 [==============================] - 0s 4ms/step - loss: 0.4448 - binary_accuracy: 0.7812 - val_loss: 0.5289 - val_binary_accuracy: 0.7676
# Epoch 43/500
# 64/64 [==============================] - 0s 4ms/step - loss: 0.4435 - binary_accuracy: 0.7792 - val_loss: 0.5233 - val_binary_accuracy: 0.7676
# Epoch 44/500
# 64/64 [==============================] - 0s 3ms/step - loss: 0.4423 - binary_accuracy: 0.7831 - val_loss: 0.5201 - val_binary_accuracy: 0.7735
# Epoch 45/500
# 64/64 [==============================] - 0s 4ms/step - loss: 0.4417 - binary_accuracy: 0.7861 - val_loss: 0.5286 - val_binary_accuracy: 0.7706
# Epoch 46/500
# 64/64 [==============================] - 0s 4ms/step - loss: 0.4409 - binary_accuracy: 0.7861 - val_loss: 0.5248 - val_binary_accuracy: 0.7618
# Epoch 47/500
# 64/64 [==============================] - 0s 6ms/step - loss: 0.4408 - binary_accuracy: 0.7831 - val_loss: 0.5238 - val_binary_accuracy: 0.7618
# Epoch 48/500
# 64/64 [==============================] - 0s 4ms/step - loss: 0.4403 - binary_accuracy: 0.7851 - val_loss: 0.5218 - val_binary_accuracy: 0.7618
# Epoch 49/500
# 64/64 [==============================] - 0s 4ms/step - loss: 0.4381 - binary_accuracy: 0.7870 - val_loss: 0.5193 - val_binary_accuracy: 0.7529
# Epoch 50/500
# 64/64 [==============================] - 0s 5ms/step - loss: 0.4391 - binary_accuracy: 0.7861 - val_loss: 0.5235 - val_binary_accuracy: 0.7676
# Epoch 51/500
# 64/64 [==============================] - 0s 3ms/step - loss: 0.4390 - binary_accuracy: 0.7880 - val_loss: 0.5229 - val_binary_accuracy: 0.7618
# Epoch 52/500
# 64/64 [==============================] - 0s 4ms/step - loss: 0.4377 - binary_accuracy: 0.7821 - val_loss: 0.5240 - val_binary_accuracy: 0.7618
# Epoch 53/500
# 64/64 [==============================] - 0s 3ms/step - loss: 0.4369 - binary_accuracy: 0.7851 - val_loss: 0.5261 - val_binary_accuracy: 0.7647
# Epoch 54/500
# 64/64 [==============================] - 0s 4ms/step - loss: 0.4350 - binary_accuracy: 0.7900 - val_loss: 0.5265 - val_binary_accuracy: 0.7588
# Epoch 55/500
# 64/64 [==============================] - 0s 4ms/step - loss: 0.4354 - binary_accuracy: 0.7890 - val_loss: 0.5343 - val_binary_accuracy: 0.7647
# Epoch 56/500
# 64/64 [==============================] - 0s 5ms/step - loss: 0.4346 - binary_accuracy: 0.7900 - val_loss: 0.5229 - val_binary_accuracy: 0.7588
# Epoch 57/500
# 64/64 [==============================] - 0s 4ms/step - loss: 0.4333 - binary_accuracy: 0.7920 - val_loss: 0.5257 - val_binary_accuracy: 0.7618
# Epoch 58/500
# 64/64 [==============================] - 0s 2ms/step - loss: 0.4342 - binary_accuracy: 0.7959 - val_loss: 0.5227 - val_binary_accuracy: 0.7588
# Epoch 59/500
# 64/64 [==============================] - 0s 3ms/step - loss: 0.4321 - binary_accuracy: 0.7939 - val_loss: 0.5203 - val_binary_accuracy: 0.7588
# Epoch 60/500
# 64/64 [==============================] - 0s 2ms/step - loss: 0.4327 - binary_accuracy: 0.7880 - val_loss: 0.5245 - val_binary_accuracy: 0.7618

# %% [markdown]
# Plot learning curves and accuracy

# %%
history_df = pd.DataFrame(history.history)

# %%
history_df.loc[:, ['binary_accuracy', 'val_binary_accuracy']].plot()
history_df.loc[:, ['loss', 'val_loss']].plot()
# Out:
# <AxesSubplot:>

# %% [markdown]
# The accuracy with the validation data remains near 75 percent
