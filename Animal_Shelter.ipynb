# %% [markdown]
# <a href="https://colab.research.google.com/github/saumilhj/projects/blob/main/Animal_Shelter.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import numpy as np
import plotly.express as px

# %% [markdown]
# Import data

# %%
df = pd.read_csv('Austin_Animal_Center_Intakes.csv')

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 124120 entries, 0 to 124119
# Data columns (total 12 columns):
#  #   Column            Non-Null Count   Dtype
# ---  ------            --------------   -----
#  0   Animal ID         124120 non-null  object
#  1   Name              85069 non-null   object
#  2   DateTime          124120 non-null  object
#  3   MonthYear         124120 non-null  object
#  4   Found Location    124120 non-null  object
#  5   Intake Type       124120 non-null  object
#  6   Intake Condition  124120 non-null  object
#  7   Animal Type       124120 non-null  object
#  8   Sex upon Intake   124119 non-null  object
#  9   Age upon Intake   124120 non-null  object
#  10  Breed             124120 non-null  object
#  11  Color             124120 non-null  object
# dtypes: object(12)
# memory usage: 11.4+ MB

# %%
df.drop(columns=['DateTime', 'Name', 'Found Location', 'Breed'], inplace=True)

# %% [markdown]
# Check duplicates and NaN

# %%
df.isna().sum()
# Out:
# Animal ID           0
# MonthYear           0
# Intake Type         0
# Intake Condition    0
# Animal Type         0
# Sex upon Intake     1
# Age upon Intake     0
# Color               0
# dtype: int64

# %%
df.dropna(axis=0, how='any', inplace=True)

# %%
df.duplicated().sum()
# Out:
# 22

# %%
df = df.drop_duplicates()

# %% [markdown]
# Cleaning data

# %%
df[['Intake Month', 'Day', 'Intake Year']] = df['MonthYear'].str.split(' ', 1, expand=True)[0].str.split('/', expand=True).astype(int)

# %%
ages = list(df['Age upon Intake'].str.split(' '))
ages_days = []
for age in ages:
  if age[1]=='years' or age[1]=='year':
    ages_days.append(abs(int(age[0]))*365)
  elif age[1]=='months' or age[1]=='month':
    ages_days.append(abs(int(age[0]))*30)
  elif age[1]=='weeks' or age[1]=='week':
    ages_days.append(abs(int(age[0]))*7)
  elif age[1]=='days' or age[1]=='day':
    ages_days.append(abs(int(age[0])))
df['Intake Age'] = ages_days
df.drop(columns=['Age upon Intake'], inplace=True)

# %%
df.drop(columns=['MonthYear', 'Day'], inplace=True)

# %%
df.head()
# Out:
#   Animal ID Intake Type Intake Condition Animal Type Sex upon Intake  \
# 0   A786884       Stray           Normal         Dog   Neutered Male
# 1   A706918       Stray           Normal         Dog   Spayed Female
# 2   A724273       Stray           Normal         Dog     Intact Male
# 3   A665644       Stray             Sick         Cat   Intact Female
# 4   A682524       Stray           Normal         Dog   Neutered Male
#
#          Color  Intake Month  Intake Year  Intake Age
# 0     Tricolor             1         2019         730
# 1  White/Liver             7         2015        2920
# 2  Sable/White             4         2016         330
# 3       Calico            10         2013          28
# 4     Tan/Gray             6         2014        1460

# %% [markdown]
# Total number of intakes per year

# %%
df_intake_per_year = df.groupby(df['Intake Year'], as_index=False).count()
df_intake_per_year.head()
# Out:
#    Intake Year  Animal ID  Intake Type  Intake Condition  Animal Type  \
# 0         2013       4181         4181              4181         4181
# 1         2014      18654        18654             18654        18654
# 2         2015      18709        18709             18709        18709
# 3         2016      17673        17673             17673        17673
# 4         2017      17559        17559             17559        17559
#
#    Sex upon Intake  Color  Intake Month  Intake Age
# 0             4181   4181          4181        4181
# 1            18654  18654         18654       18654
# 2            18709  18709         18709       18709
# 3            17673  17673         17673       17673
# 4            17559  17559         17559       17559

# %%
fig = px.bar(df_intake_per_year, x='Intake Year', y='Animal ID',
             title='Total number of intakes every year',
             labels={'Animal ID': 'Total animals'})
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script src="https://cdn.plot.ly/plotly-2.8.3.min.js"></script>                <div id="56eeab3c-1142-4822-bfb0-ccf7e32c07d1" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("56eeab3c-1142-4822-bfb0-ccf7e32c07d1")) {                    Plotly.newPlot(                        "56eeab3c-1142-4822-bfb0-ccf7e32c07d1",                        [{"alignmentgroup":"True","hovertemplate":"Intake Year=%{x}<br>Total animals=%{y}<extra></extra>","legendgroup":"","marker":{"color":"#636efa","pattern":{"shape":""}},"name":"","offsetgroup":"","orientation":"v","showlegend":false,"textposition":"auto","x":[2013,2014,2015,2016,2017,2018,2019,2020,2021],"xaxis":"x","y":[4181,18654,18709,17673,17559,16975,19726,9583,1037],"yaxis":"y","type":"bar"}],                        {"template":{"data":{"bar":[{"error_x":{"color":"#2a3f5f"},"error_y":{"color":"#2a3f5f"},"marker":{"line":{"color":"#E5ECF6","width":0.5},"pattern":{"fillmode":"overlay","size":10,"solidity":0.2}},"type":"bar"}],"barpolar":[{"marker":{"line":{"color":"#E5ECF6","width":0.5},"pattern":{"fillmode":"overlay","size":10,"solidity":0.2}},"type":"barpolar"}],"carpet":[{"aaxis":{"endlinecolor":"#2a3f5f","gridcolor":"white","linecolor":"white","minorgridcolor":"white","startlinecolor":"#2a3f5f"},"baxis":{"endlinecolor":"#2a3f5f","gridcolor":"white","linecolor":"white","minorgridcolor":"white","startlinecolor":"#2a3f5f"},"type":"carpet"}],"choropleth":[{"colorbar":{"outlinewidth":0,"ticks":""},"type":"choropleth"}],"contour":[{"colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]],"type":"contour"}],"contourcarpet":[{"colorbar":{"outlinewidth":0,"ticks":""},"type":"contourcarpet"}],"heatmap":[{"colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]],"type":"heatmap"}],"heatmapgl":[{"colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]],"type":"heatmapgl"}],"histogram":[{"marker":{"pattern":{"fillmode":"overlay","size":10,"solidity":0.2}},"type":"histogram"}],"histogram2d":[{"colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]],"type":"histogram2d"}],"histogram2dcontour":[{"colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]],"type":"histogram2dcontour"}],"mesh3d":[{"colorbar":{"outlinewidth":0,"ticks":""},"type":"mesh3d"}],"parcoords":[{"line":{"colorbar":{"outlinewidth":0,"ticks":""}},"type":"parcoords"}],"pie":[{"automargin":true,"type":"pie"}],"scatter":[{"marker":{"colorbar":{"outlinewidth":0,"ticks":""}} ...

# %% [markdown]
# Intake type per year

# %%
df_intake_per_year_and_type = df.groupby(['Intake Year', 'Intake Type'], as_index=False).count()
df_intake_per_year_and_type.head()
# Out:
#    Intake Year         Intake Type  Animal ID  Intake Condition  Animal Type  \
# 0         2013  Euthanasia Request         31                31           31
# 1         2013     Owner Surrender        827               827          827
# 2         2013       Public Assist        244               244          244
# 3         2013               Stray       2884              2884         2884
# 4         2013            Wildlife        195               195          195
#
#    Sex upon Intake  Color  Intake Month  Intake Age
# 0               31     31            31          31
# 1              827    827           827         827
# 2              244    244           244         244
# 3             2884   2884          2884        2884
# 4              195    195           195         195

# %%
fig = px.bar(df_intake_per_year_and_type, x='Intake Year', y='Animal ID', color='Intake Type',
             title='Category of intakes every year',
             labels={'Animal ID': 'Total animals'})
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script src="https://cdn.plot.ly/plotly-2.8.3.min.js"></script>                <div id="18dbae30-5842-4fbf-83da-a1b6c0e28f91" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("18dbae30-5842-4fbf-83da-a1b6c0e28f91")) {                    Plotly.newPlot(                        "18dbae30-5842-4fbf-83da-a1b6c0e28f91",                        [{"alignmentgroup":"True","hovertemplate":"Intake Type=Euthanasia Request<br>Intake Year=%{x}<br>Total animals=%{y}<extra></extra>","legendgroup":"Euthanasia Request","marker":{"color":"#636efa","pattern":{"shape":""}},"name":"Euthanasia Request","offsetgroup":"Euthanasia Request","orientation":"v","showlegend":true,"textposition":"auto","x":[2013,2014,2015,2016,2017,2018,2019],"xaxis":"x","y":[31,110,78,24,8,2,4],"yaxis":"y","type":"bar"},{"alignmentgroup":"True","hovertemplate":"Intake Type=Owner Surrender<br>Intake Year=%{x}<br>Total animals=%{y}<extra></extra>","legendgroup":"Owner Surrender","marker":{"color":"#EF553B","pattern":{"shape":""}},"name":"Owner Surrender","offsetgroup":"Owner Surrender","orientation":"v","showlegend":true,"textposition":"auto","x":[2013,2014,2015,2016,2017,2018,2019,2020,2021],"xaxis":"x","y":[827,3382,3231,3360,3579,3305,4291,2388,236],"yaxis":"y","type":"bar"},{"alignmentgroup":"True","hovertemplate":"Intake Type=Public Assist<br>Intake Year=%{x}<br>Total animals=%{y}<extra></extra>","legendgroup":"Public Assist","marker":{"color":"#00cc96","pattern":{"shape":""}},"name":"Public Assist","offsetgroup":"Public Assist","orientation":"v","showlegend":true,"textposition":"auto","x":[2013,2014,2015,2016,2017,2018,2019,2020,2021],"xaxis":"x","y":[244,1149,1082,1149,1180,1087,1042,599,84],"yaxis":"y","type":"bar"},{"alignmentgroup":"True","hovertemplate":"Intake Type=Stray<br>Intake Year=%{x}<br>Total animals=%{y}<extra></extra>","legendgroup":"Stray","marker":{"color":"#ab63fa","pattern":{"shape":""}},"name":"Stray","offsetgroup":"Stray","orientation":"v","showlegend":true,"textposition":"auto","x":[2013,2014,2015,2016,2017,2018,2019,2020,2021],"xaxis":"x","y":[2884,13125,13680,12370,12009,12010,13910,5821,638],"yaxis":"y","type":"bar"},{"alignmentgroup":"True","hovertemplate":"Intake Type=Wildlife<br>Intake Year=%{x}<br>Total animals=%{y}<extra></extra>","legendgroup":"Wildlife","marker":{"color":"#FFA15A","pattern":{"shape":""}},"name":"Wildlife","offsetgroup":"Wildlife","orientation":"v","showlegend":true,"textposition":"auto","x":[2013,2014,2015,2016,2017,2018,2019,2020,2021],"xaxis":"x","y":[195,888,638,770,783,571,479,514,57],"yaxis":"y","type":"bar"},{"alignmentgroup":"True","hovertemplate":"Intake Type=Abandoned<br>Intake Year=%{x}<br>Total animals=%{y}<extra></extra>","legendgroup":"Abandoned","marker":{"color":"#19d3f3","pattern":{"shape":""}},"name":"Abandoned","offsetgroup":"Abandoned","orientation":"v","showlegend":true,"textposition":"auto","x":[2020,2021],"xaxis":"x","y":[261,22],"yaxis":"y","type":"bar"}],                        {"template":{"data":{"bar":[{"error_x":{"color":"#2a3f5f"},"error_y":{"color":"#2a3f5f"},"marker":{"line":{"color":"#E5ECF6","width":0.5},"pattern":{"fillmode":"overlay","size":10,"solidity":0.2}},"type":"bar"}],"barpolar":[{"marker":{"line":{"color":"#E5ECF6","width":0.5},"pattern":{"fillmode":"overlay","size":10,"solidity":0.2}},"type":"barpolar"}],"carpet":[{"aaxis":{"endlinecolor":"#2a3f5f","gridcolor":"white","linecolor":"white","minorgridcolor":"white","startlinecolor":"#2a3f5f"},"baxis":{"endlinecolor":"#2a3f5f","gridcolor":"white","linecolor":"white","minorgridcolor":"white","startlinecolor":"#2a3f5f"},"type":"carpet"}],"choropleth":[{"colorbar":{"outlinewidth":0,"ticks":""},"type":"choropleth"}],"contour":[{"colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.222 ...

# %% [markdown]
# Intake condition of animal per year

# %%
df_intake_per_year_and_condition = df.groupby(['Intake Year', 'Intake Condition'], as_index=False).count()
df_intake_per_year_and_condition.head()
# Out:
#    Intake Year Intake Condition  Animal ID  Intake Type  Animal Type  \
# 0         2013             Aged         26           26           26
# 1         2013            Feral          6            6            6
# 2         2013          Injured        224          224          224
# 3         2013           Normal       3640         3640         3640
# 4         2013          Nursing         57           57           57
#
#    Sex upon Intake  Color  Intake Month  Intake Age
# 0               26     26            26          26
# 1                6      6             6           6
# 2              224    224           224         224
# 3             3640   3640          3640        3640
# 4               57     57            57          57

# %%
fig = px.bar(df_intake_per_year_and_condition, x='Intake Year', y='Animal ID', color='Intake Condition',
             title='Condition of animal every year',
             labels={'Animal ID': 'Total animals'})
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script src="https://cdn.plot.ly/plotly-2.8.3.min.js"></script>                <div id="d1e96f1f-59dd-485b-b5b1-9ff549ef8599" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("d1e96f1f-59dd-485b-b5b1-9ff549ef8599")) {                    Plotly.newPlot(                        "d1e96f1f-59dd-485b-b5b1-9ff549ef8599",                        [{"alignmentgroup":"True","hovertemplate":"Intake Condition=Aged<br>Intake Year=%{x}<br>Total animals=%{y}<extra></extra>","legendgroup":"Aged","marker":{"color":"#636efa","pattern":{"shape":""}},"name":"Aged","offsetgroup":"Aged","orientation":"v","showlegend":true,"textposition":"auto","x":[2013,2014,2015,2016,2017,2018,2019,2020,2021],"xaxis":"x","y":[26,69,81,86,47,34,39,43,5],"yaxis":"y","type":"bar"},{"alignmentgroup":"True","hovertemplate":"Intake Condition=Feral<br>Intake Year=%{x}<br>Total animals=%{y}<extra></extra>","legendgroup":"Feral","marker":{"color":"#EF553B","pattern":{"shape":""}},"name":"Feral","offsetgroup":"Feral","orientation":"v","showlegend":true,"textposition":"auto","x":[2013,2014,2015,2016,2017,2018,2019,2020,2021],"xaxis":"x","y":[6,22,30,13,18,7,4,6,2],"yaxis":"y","type":"bar"},{"alignmentgroup":"True","hovertemplate":"Intake Condition=Injured<br>Intake Year=%{x}<br>Total animals=%{y}<extra></extra>","legendgroup":"Injured","marker":{"color":"#00cc96","pattern":{"shape":""}},"name":"Injured","offsetgroup":"Injured","orientation":"v","showlegend":true,"textposition":"auto","x":[2013,2014,2015,2016,2017,2018,2019,2020,2021],"xaxis":"x","y":[224,960,926,929,818,793,929,924,135],"yaxis":"y","type":"bar"},{"alignmentgroup":"True","hovertemplate":"Intake Condition=Normal<br>Intake Year=%{x}<br>Total animals=%{y}<extra></extra>","legendgroup":"Normal","marker":{"color":"#ab63fa","pattern":{"shape":""}},"name":"Normal","offsetgroup":"Normal","orientation":"v","showlegend":true,"textposition":"auto","x":[2013,2014,2015,2016,2017,2018,2019,2020,2021],"xaxis":"x","y":[3640,16148,16391,15547,15714,15227,17113,7376,776],"yaxis":"y","type":"bar"},{"alignmentgroup":"True","hovertemplate":"Intake Condition=Nursing<br>Intake Year=%{x}<br>Total animals=%{y}<extra></extra>","legendgroup":"Nursing","marker":{"color":"#FFA15A","pattern":{"shape":""}},"name":"Nursing","offsetgroup":"Nursing","orientation":"v","showlegend":true,"textposition":"auto","x":[2013,2014,2015,2016,2017,2018,2019,2020,2021],"xaxis":"x","y":[57,483,588,377,367,341,860,416,35],"yaxis":"y","type":"bar"},{"alignmentgroup":"True","hovertemplate":"Intake Condition=Other<br>Intake Year=%{x}<br>Total animals=%{y}<extra></extra>","legendgroup":"Other","marker":{"color":"#19d3f3","pattern":{"shape":""}},"name":"Other","offsetgroup":"Other","orientation":"v","showlegend":true,"textposition":"auto","x":[2013,2014,2015,2016,2017,2018,2019,2020,2021],"xaxis":"x","y":[16,39,33,25,31,30,39,12,4],"yaxis":"y","type":"bar"},{"alignmentgroup":"True","hovertemplate":"Intake Condition=Pregnant<br>Intake Year=%{x}<br>Total animals=%{y}<extra></extra>","legendgroup":"Pregnant","marker":{"color":"#FF6692","pattern":{"shape":""}},"name":"Pregnant","offsetgroup":"Pregnant","orientation":"v","showlegend":true,"textposition":"auto","x":[2013,2014,2015,2016,2017,2018,2019,2020],"xaxis":"x","y":[1,12,10,18,6,6,13,11],"yaxis":"y","type":"bar"},{"alignmentgroup":"True","hovertemplate":"Intake Condition=Sick<br>Intake Year=%{x}<br>Total animals=%{y}<extra></extra>","legendgroup":"Sick","marker":{"color":"#B6E880","pattern":{"shape":""}},"name":"Sick","offsetgroup":"Sick","orientation":"v","showlegend":true,"textposition":"auto","x":[2013,2014,2015,2016,2017,2018,2019,2020,2021],"xaxis":"x","y":[211,921,650,678,558,537,719,728,74],"yaxis":"y","type":"bar"},{"alignmentgroup":"True","hovertemplate":"Intake Condition=Behavior<br>Intake Year=%{x}< ...

# %% [markdown]
# Distribution of animal type per year

# %%
df_intake_per_year_and_animal = df.groupby(['Intake Year', 'Animal Type'], as_index=False).count()
df_intake_per_year_and_animal.head()
# Out:
#    Intake Year Animal Type  Animal ID  Intake Type  Intake Condition  \
# 0         2013        Bird          5            5                 5
# 1         2013         Cat       1309         1309              1309
# 2         2013         Dog       2633         2633              2633
# 3         2013   Livestock          1            1                 1
# 4         2013       Other        233          233               233
#
#    Sex upon Intake  Color  Intake Month  Intake Age
# 0                5      5             5           5
# 1             1309   1309          1309        1309
# 2             2633   2633          2633        2633
# 3                1      1             1           1
# 4              233    233           233         233

# %%
fig = px.bar(df_intake_per_year_and_animal, x='Intake Year', y='Animal ID', color='Animal Type',
             title='Type of animal per year',
             labels={'Animal ID': 'Total animals'})
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script src="https://cdn.plot.ly/plotly-2.8.3.min.js"></script>                <div id="4813a1be-4ddb-48ed-a654-b514f2ffcfce" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("4813a1be-4ddb-48ed-a654-b514f2ffcfce")) {                    Plotly.newPlot(                        "4813a1be-4ddb-48ed-a654-b514f2ffcfce",                        [{"alignmentgroup":"True","hovertemplate":"Animal Type=Bird<br>Intake Year=%{x}<br>Total animals=%{y}<extra></extra>","legendgroup":"Bird","marker":{"color":"#636efa","pattern":{"shape":""}},"name":"Bird","offsetgroup":"Bird","orientation":"v","showlegend":true,"textposition":"auto","x":[2013,2014,2015,2016,2017,2018,2019,2020,2021],"xaxis":"x","y":[5,53,47,138,87,111,95,43,7],"yaxis":"y","type":"bar"},{"alignmentgroup":"True","hovertemplate":"Animal Type=Cat<br>Intake Year=%{x}<br>Total animals=%{y}<extra></extra>","legendgroup":"Cat","marker":{"color":"#EF553B","pattern":{"shape":""}},"name":"Cat","offsetgroup":"Cat","orientation":"v","showlegend":true,"textposition":"auto","x":[2013,2014,2015,2016,2017,2018,2019,2020,2021],"xaxis":"x","y":[1309,6937,7484,6632,6488,6018,7881,3448,249],"yaxis":"y","type":"bar"},{"alignmentgroup":"True","hovertemplate":"Animal Type=Dog<br>Intake Year=%{x}<br>Total animals=%{y}<extra></extra>","legendgroup":"Dog","marker":{"color":"#00cc96","pattern":{"shape":""}},"name":"Dog","offsetgroup":"Dog","orientation":"v","showlegend":true,"textposition":"auto","x":[2013,2014,2015,2016,2017,2018,2019,2020,2021],"xaxis":"x","y":[2633,10567,10326,9932,9938,10001,10928,5418,693],"yaxis":"y","type":"bar"},{"alignmentgroup":"True","hovertemplate":"Animal Type=Livestock<br>Intake Year=%{x}<br>Total animals=%{y}<extra></extra>","legendgroup":"Livestock","marker":{"color":"#ab63fa","pattern":{"shape":""}},"name":"Livestock","offsetgroup":"Livestock","orientation":"v","showlegend":true,"textposition":"auto","x":[2013,2014,2015,2016,2017,2018,2019,2020],"xaxis":"x","y":[1,3,2,1,1,5,7,2],"yaxis":"y","type":"bar"},{"alignmentgroup":"True","hovertemplate":"Animal Type=Other<br>Intake Year=%{x}<br>Total animals=%{y}<extra></extra>","legendgroup":"Other","marker":{"color":"#FFA15A","pattern":{"shape":""}},"name":"Other","offsetgroup":"Other","orientation":"v","showlegend":true,"textposition":"auto","x":[2013,2014,2015,2016,2017,2018,2019,2020,2021],"xaxis":"x","y":[233,1094,850,970,1045,840,815,672,88],"yaxis":"y","type":"bar"}],                        {"template":{"data":{"bar":[{"error_x":{"color":"#2a3f5f"},"error_y":{"color":"#2a3f5f"},"marker":{"line":{"color":"#E5ECF6","width":0.5},"pattern":{"fillmode":"overlay","size":10,"solidity":0.2}},"type":"bar"}],"barpolar":[{"marker":{"line":{"color":"#E5ECF6","width":0.5},"pattern":{"fillmode":"overlay","size":10,"solidity":0.2}},"type":"barpolar"}],"carpet":[{"aaxis":{"endlinecolor":"#2a3f5f","gridcolor":"white","linecolor":"white","minorgridcolor":"white","startlinecolor":"#2a3f5f"},"baxis":{"endlinecolor":"#2a3f5f","gridcolor":"white","linecolor":"white","minorgridcolor":"white","startlinecolor":"#2a3f5f"},"type":"carpet"}],"choropleth":[{"colorbar":{"outlinewidth":0,"ticks":""},"type":"choropleth"}],"contour":[{"colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]],"type":"contour"}],"contourcarpet":[{"colorbar":{"outlinewidth":0,"ticks":""},"type":"contourcarpet"}],"heatmap":[{"colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.44444444444 ...

# %% [markdown]
# Gender distribution of animals

# %%
df_animal_gender = df.groupby(['Animal Type', 'Sex upon Intake'], as_index=False).count()
df_animal_gender.head()
# Out:
#   Animal Type Sex upon Intake  Animal ID  Intake Type  Intake Condition  \
# 0        Bird   Intact Female         81           81                81
# 1        Bird     Intact Male        160          160               160
# 2        Bird         Unknown        345          345               345
# 3         Cat   Intact Female      16943        16943             16943
# 4         Cat     Intact Male      15989        15989             15989
#
#    Color  Intake Month  Intake Year  Intake Age
# 0     81            81           81          81
# 1    160           160          160         160
# 2    345           345          345         345
# 3  16943         16943        16943       16943
# 4  15989         15989        15989       15989

# %%
fig = px.bar(df_animal_gender, x='Animal Type', y='Animal ID', color='Sex upon Intake',
             title='Gender distribution of the animals',
             labels={'Animal ID': 'Total animals', 'Sex upon Intake': 'Gender'})
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script src="https://cdn.plot.ly/plotly-2.8.3.min.js"></script>                <div id="069a5831-a371-42e8-9a49-0e3f78a483b9" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("069a5831-a371-42e8-9a49-0e3f78a483b9")) {                    Plotly.newPlot(                        "069a5831-a371-42e8-9a49-0e3f78a483b9",                        [{"alignmentgroup":"True","hovertemplate":"Gender=Intact Female<br>Animal Type=%{x}<br>Total animals=%{y}<extra></extra>","legendgroup":"Intact Female","marker":{"color":"#636efa","pattern":{"shape":""}},"name":"Intact Female","offsetgroup":"Intact Female","orientation":"v","showlegend":true,"textposition":"auto","x":["Bird","Cat","Dog","Livestock","Other"],"xaxis":"x","y":[81,16943,20679,8,404],"yaxis":"y","type":"bar"},{"alignmentgroup":"True","hovertemplate":"Gender=Intact Male<br>Animal Type=%{x}<br>Total animals=%{y}<extra></extra>","legendgroup":"Intact Male","marker":{"color":"#EF553B","pattern":{"shape":""}},"name":"Intact Male","offsetgroup":"Intact Male","orientation":"v","showlegend":true,"textposition":"auto","x":["Bird","Cat","Dog","Livestock","Other"],"xaxis":"x","y":[160,15989,23615,5,541],"yaxis":"y","type":"bar"},{"alignmentgroup":"True","hovertemplate":"Gender=Unknown<br>Animal Type=%{x}<br>Total animals=%{y}<extra></extra>","legendgroup":"Unknown","marker":{"color":"#00cc96","pattern":{"shape":""}},"name":"Unknown","offsetgroup":"Unknown","orientation":"v","showlegend":true,"textposition":"auto","x":["Bird","Cat","Dog","Livestock","Other"],"xaxis":"x","y":[345,3884,457,8,5536],"yaxis":"y","type":"bar"},{"alignmentgroup":"True","hovertemplate":"Gender=Neutered Male<br>Animal Type=%{x}<br>Total animals=%{y}<extra></extra>","legendgroup":"Neutered Male","marker":{"color":"#ab63fa","pattern":{"shape":""}},"name":"Neutered Male","offsetgroup":"Neutered Male","orientation":"v","showlegend":true,"textposition":"auto","x":["Cat","Dog","Livestock","Other"],"xaxis":"x","y":[4960,14106,1,71],"yaxis":"y","type":"bar"},{"alignmentgroup":"True","hovertemplate":"Gender=Spayed Female<br>Animal Type=%{x}<br>Total animals=%{y}<extra></extra>","legendgroup":"Spayed Female","marker":{"color":"#FFA15A","pattern":{"shape":""}},"name":"Spayed Female","offsetgroup":"Spayed Female","orientation":"v","showlegend":true,"textposition":"auto","x":["Cat","Dog","Other"],"xaxis":"x","y":[4670,11579,55],"yaxis":"y","type":"bar"}],                        {"template":{"data":{"bar":[{"error_x":{"color":"#2a3f5f"},"error_y":{"color":"#2a3f5f"},"marker":{"line":{"color":"#E5ECF6","width":0.5},"pattern":{"fillmode":"overlay","size":10,"solidity":0.2}},"type":"bar"}],"barpolar":[{"marker":{"line":{"color":"#E5ECF6","width":0.5},"pattern":{"fillmode":"overlay","size":10,"solidity":0.2}},"type":"barpolar"}],"carpet":[{"aaxis":{"endlinecolor":"#2a3f5f","gridcolor":"white","linecolor":"white","minorgridcolor":"white","startlinecolor":"#2a3f5f"},"baxis":{"endlinecolor":"#2a3f5f","gridcolor":"white","linecolor":"white","minorgridcolor":"white","startlinecolor":"#2a3f5f"},"type":"carpet"}],"choropleth":[{"colorbar":{"outlinewidth":0,"ticks":""},"type":"choropleth"}],"contour":[{"colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]],"type":"contour"}],"contourcarpet":[{"colorbar":{"outlinewidth":0,"ticks":""},"type":"contourcarpet"}],"heatmap":[{"colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.555 ...

# %% [markdown]
# Intake type of every animal

# %%
df_animal_condition = df.groupby(['Animal Type', 'Intake Type'], as_index=False).count()
df_animal_condition.head()
# Out:
#   Animal Type         Intake Type  Animal ID  Intake Condition  \
# 0        Bird  Euthanasia Request          3                 3
# 1        Bird     Owner Surrender         61                61
# 2        Bird       Public Assist        128               128
# 3        Bird               Stray        289               289
# 4        Bird            Wildlife        105               105
#
#    Sex upon Intake  Color  Intake Month  Intake Year  Intake Age
# 0                3      3             3            3           3
# 1               61     61            61           61          61
# 2              128    128           128          128         128
# 3              289    289           289          289         289
# 4              105    105           105          105         105

# %%
fig = px.bar(df_animal_condition, x='Animal Type', y='Animal ID', color='Intake Type',
             title='Type of intake of every animal')
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script src="https://cdn.plot.ly/plotly-2.8.3.min.js"></script>                <div id="bb1b4e0b-0711-48b4-b8dc-f8dd39f3fdef" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("bb1b4e0b-0711-48b4-b8dc-f8dd39f3fdef")) {                    Plotly.newPlot(                        "bb1b4e0b-0711-48b4-b8dc-f8dd39f3fdef",                        [{"alignmentgroup":"True","hovertemplate":"Intake Type=Euthanasia Request<br>Animal Type=%{x}<br>Animal ID=%{y}<extra></extra>","legendgroup":"Euthanasia Request","marker":{"color":"#636efa","pattern":{"shape":""}},"name":"Euthanasia Request","offsetgroup":"Euthanasia Request","orientation":"v","showlegend":true,"textposition":"auto","x":["Bird","Cat","Dog","Other"],"xaxis":"x","y":[3,58,182,14],"yaxis":"y","type":"bar"},{"alignmentgroup":"True","hovertemplate":"Intake Type=Owner Surrender<br>Animal Type=%{x}<br>Animal ID=%{y}<extra></extra>","legendgroup":"Owner Surrender","marker":{"color":"#EF553B","pattern":{"shape":""}},"name":"Owner Surrender","offsetgroup":"Owner Surrender","orientation":"v","showlegend":true,"textposition":"auto","x":["Bird","Cat","Dog","Livestock","Other"],"xaxis":"x","y":[61,9126,14812,1,599],"yaxis":"y","type":"bar"},{"alignmentgroup":"True","hovertemplate":"Intake Type=Public Assist<br>Animal Type=%{x}<br>Animal ID=%{y}<extra></extra>","legendgroup":"Public Assist","marker":{"color":"#00cc96","pattern":{"shape":""}},"name":"Public Assist","offsetgroup":"Public Assist","orientation":"v","showlegend":true,"textposition":"auto","x":["Bird","Cat","Dog","Livestock","Other"],"xaxis":"x","y":[128,1035,6144,1,308],"yaxis":"y","type":"bar"},{"alignmentgroup":"True","hovertemplate":"Intake Type=Stray<br>Animal Type=%{x}<br>Animal ID=%{y}<extra></extra>","legendgroup":"Stray","marker":{"color":"#ab63fa","pattern":{"shape":""}},"name":"Stray","offsetgroup":"Stray","orientation":"v","showlegend":true,"textposition":"auto","x":["Bird","Cat","Dog","Livestock","Other"],"xaxis":"x","y":[289,36121,49137,20,880],"yaxis":"y","type":"bar"},{"alignmentgroup":"True","hovertemplate":"Intake Type=Wildlife<br>Animal Type=%{x}<br>Animal ID=%{y}<extra></extra>","legendgroup":"Wildlife","marker":{"color":"#FFA15A","pattern":{"shape":""}},"name":"Wildlife","offsetgroup":"Wildlife","orientation":"v","showlegend":true,"textposition":"auto","x":["Bird","Other"],"xaxis":"x","y":[105,4790],"yaxis":"y","type":"bar"},{"alignmentgroup":"True","hovertemplate":"Intake Type=Abandoned<br>Animal Type=%{x}<br>Animal ID=%{y}<extra></extra>","legendgroup":"Abandoned","marker":{"color":"#19d3f3","pattern":{"shape":""}},"name":"Abandoned","offsetgroup":"Abandoned","orientation":"v","showlegend":true,"textposition":"auto","x":["Cat","Dog","Other"],"xaxis":"x","y":[106,161,16],"yaxis":"y","type":"bar"}],                        {"template":{"data":{"bar":[{"error_x":{"color":"#2a3f5f"},"error_y":{"color":"#2a3f5f"},"marker":{"line":{"color":"#E5ECF6","width":0.5},"pattern":{"fillmode":"overlay","size":10,"solidity":0.2}},"type":"bar"}],"barpolar":[{"marker":{"line":{"color":"#E5ECF6","width":0.5},"pattern":{"fillmode":"overlay","size":10,"solidity":0.2}},"type":"barpolar"}],"carpet":[{"aaxis":{"endlinecolor":"#2a3f5f","gridcolor":"white","linecolor":"white","minorgridcolor":"white","startlinecolor":"#2a3f5f"},"baxis":{"endlinecolor":"#2a3f5f","gridcolor":"white","linecolor":"white","minorgridcolor":"white","startlinecolor":"#2a3f5f"},"type":"carpet"}],"choropleth":[{"colorbar":{"outlinewidth":0,"ticks":""},"type":"choropleth"}],"contour":[{"colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778," ...
